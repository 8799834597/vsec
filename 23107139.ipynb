# %%
a=10
b=5
c=a+b
print(c)
# Out:
# 15

# %%
name=input("enter the name:")
age=int(input("enter the number:"))

print("Name:",name)
print("Age:",age)
# Out:
# enter the name: archu
# enter the number: 21
# Name: archu
# Age: 21
